# %%
# !pip install spotipy --upgrade

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
os.environ ['SPOTIPY_CLIENT_ID']='c97d261239c2476d9b85f08179450fc1'
os.environ ['SPOTIPY_CLIENT_SECRET']='9262159ff2264fefa2568620aab11d97'
os.environ ['SPOTIPY_REDIRECT_URI']='http://127.0.0.1:5000'

auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print(f"{i + 1 + playlists['offset']:4d} {playlist['uri']} {playlist['name']}")
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:0NfjMqrzcGKVsbYZmhf4Md Classic Honky Tonk
#    2 spotify:playlist:1scnlLVq91NGtsA9sh0hfw Nicholas Sparks | Songs from the Soundtracks
#    3 spotify:playlist:2NFOUmp2wyR5CrXtKDkUkB 1960s Nostalgia
#    4 spotify:playlist:1o2bTwofazfzElA5mXGf2t Breakup Blues
#    5 spotify:playlist:6cdV0hVW2suJaMOxzwE46S I Hate My Job.
#    6 spotify:playlist:2uhsnHgI4F2eFyvoMHY0GR Instrumental Rock
#    7 spotify:playlist:2uVP1agvV5rba3MqLQ0pzy Avant Folk
#    8 spotify:playlist:0BbcjurkvWrkWxKKLzcqIP The Perfect Crafternoon
#    9 spotify:playlist:44XJR1i3Vl2B3acOEYwinE Power Ballads
#   10 spotify:playlist:2YeGkAUQhmO8TCjSMbFYWf Energy + Positivity
#   11 spotify:playlist:0op6xwVK9pVhcxozSQPEsJ Namaste
#   12 spotify:playlist:2Ph68VcwRfqRdnrKhY3oPS Rustic Romance Wedding
#   13 spotify:playlist:2VxQy0Q22k1gP542tzaMCN Word of Mouth
#   14 spotify:playlist:0sDO43KAaJUWIYassTKWYf Indie Strings
#   15 spotify:playlist:2B64RN7KJte5x6iXgg02tv Vinyasa Flow
# ...

# %%
Thaman_uri = 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(Thaman_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Game Changer (Tamil)
# Game Changer (Hindi)
# Game Changer (Telugu)
# Baby John (Original Motion Picture Soundtrack)
# Bheemla Nayak - OST
# Guntur Kaaram - OST
# Skanda (Orginal Background Score)
# BRO BGM
# BRO
# BRO
# BRO
# BRO
# Varisu Original Sound Track
# Ala Vaikunthapurramuloo - OST
# Varisu (Dialogues)
# Vaarasudu (Dialogues)
# Thamans Super Hits
# Varisu (Cine Audio)
# Vaarasudu (Cine Audio)
# Thaman Beats
# Bheemla Nayak
# Vakeel Saab OST
# Tholi Prema BGM
# Ala Vaikunthapurramuloo
# Mr. Majnu (Original Background Score)
# Aravindha Sametha (Original Motion Picture Soundtrack)
# Thiri (Original Motion Picture Soundtrack)
# Mahanubhavudu
# Dictator (Original Motion Picture Soundtrack)
# Love Story
# Greekuveerudu
# Thadaiyara Thakka
# Nippu
# Veera
# Mirapakay
# Brindaavanam
# Thillalangadi (Original Motion Picture Soundtrack)
# Moscowin Kaveri (Original Motion Picture Soundtrack)

# %%
DSP_uri = 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(DSP_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Kuberaa (Tamil)
# Kuberaa (Malayalam)
# Kuberaa (Kannada)
# Kuberaa (Hindi)
# Kuberaa
# Pushpa 2 The Rule (DIALOGUES) [TAMIL]
# Pushpa 2 The Rule (DIALOGUES) [MALAYALAM]
# Pushpa 2 The Rule (DIALOGUES) [KANNADA]
# Pushpa 2 The Rule (DIALOGUES) [TELUGU]
# Pushpa 2 The Rule (DIALOGUES) [HINDI]
# Pushpa 2 The Rule Ost
# Rathnam (Tamil)
# Rathnam
# Pushpa The Rise - OST
# Drishyam 2 (Original Background Score)
# Ready (Cine Audio)
# National Crush Rashmika Mandanna Hit Songs
# Fresh Face To Tollywood
# Rowdy Boys
# S/o Satyamurthy
# Sakala Devatha Stothrams, Vol. 1
# Uppena
# Manmadan Ambu (Original Motion Picture Soundtrack)
# Rockstar Dsp Birthday Special Hit Songs 2019
# Expression Queen Trisha
# Kotha Kothagaa
# Maharshi
# Rockstar Dsp - Musical Journey
# Dsp Musical Hits
# Golden Star Ganesh Romantic Hits
# Puli (Telugu) [Original Motion Picture Soundtrack]
# Son Of Sathyamoorthi (Original Motion Picture Soundtrack)
# Son Of Satyamurthy
# Devi
# Legend (Telugu)
# Jai Ho
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + str(track['preview_url']))  # handles None safely
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Bujji Thalli (From "Thandel")
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b273b21d3fb220ac724c150b9d20
#
# track    : Oo Antava Oo Oo Antava (From "Pushpa - The Rise")(Telugu)
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b2735d10ca5f50f7e9abca322956
#
# track    : Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b273bde2708d57b1fbb64ca2a233
#
# track    : Poyiraa Mama
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b273c5e603c00c6b3527ff6e95b1
#
# track    : Uppenantha
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b2738335d4c9f1240433714f0a33
#
# track    : Daddy Mummy
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b273e1e5abb14d9daf6618d19273
#
# track    : Peelings (From "Pushpa 2 The Rule") [TELUGU]
# audio    : None
# cover art: https://i.scdn.co/image/ab67616d0000b2739c3b8606a83a49694b48a126
#
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set up the Spotify API client
spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

# Ask user for artist name
name = "Thaman"

# Search for the artist
results = spotify.search(q='artist:' + name, type='artist')
items = results['artists']['items']

# Check and display result
if items:
    artist = items[0]
    print("Artist:", artist['name'])
    if artist['images']:
        print("Image URL:", artist['images'][0]['url'])
    else:
        print("No image available for this artist.")
else:
    print('Artist Not Found')
# Out:
# Artist: Thaman S
# Image URL: https://i.scdn.co/image/ab6761610000e5eb1edc6d40afbea5426d0cfe0f

# %%
thaman_uri = 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'
results = sp.artist_albums(thaman_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])
for album in albums:
    print(album['name'])
# Out:
# Game Changer (Tamil)
# Game Changer (Hindi)
# Game Changer (Telugu)
# Baby John (Original Motion Picture Soundtrack)
# Bheemla Nayak - OST
# Guntur Kaaram - OST
# Skanda (Orginal Background Score)
# BRO BGM
# BRO
# BRO
# BRO
# BRO
# Varisu Original Sound Track
# Ala Vaikunthapurramuloo - OST
# Varisu (Dialogues)
# Vaarasudu (Dialogues)
# Thamans Super Hits
# Varisu (Cine Audio)
# Vaarasudu (Cine Audio)
# Thaman Beats
# Bheemla Nayak
# Vakeel Saab OST
# Tholi Prema BGM
# Ala Vaikunthapurramuloo
# Mr. Majnu (Original Background Score)
# Aravindha Sametha (Original Motion Picture Soundtrack)
# Thiri (Original Motion Picture Soundtrack)
# Mahanubhavudu
# Dictator (Original Motion Picture Soundtrack)
# Love Story
# Greekuveerudu
# Thadaiyara Thakka
# Nippu
# Veera
# Mirapakay
# Brindaavanam
# Thillalangadi (Original Motion Picture Soundtrack)
# Moscowin Kaveri (Original Motion Picture Soundtrack)

# %%
dsp_uri = 'spotify:artist:5sSzCxHtgL82pYDvx2QyEU'
results = sp.artist_albums(dsp_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])
for album in albums:
    print(album['name'])
# Out:
# Kuberaa (Tamil)
# Kuberaa (Malayalam)
# Kuberaa (Kannada)
# Kuberaa (Hindi)
# Kuberaa
# Pushpa 2 The Rule (DIALOGUES) [TAMIL]
# Pushpa 2 The Rule (DIALOGUES) [MALAYALAM]
# Pushpa 2 The Rule (DIALOGUES) [KANNADA]
# Pushpa 2 The Rule (DIALOGUES) [TELUGU]
# Pushpa 2 The Rule (DIALOGUES) [HINDI]
# Pushpa 2 The Rule Ost
# Rathnam (Tamil)
# Rathnam
# Pushpa The Rise - OST
# Drishyam 2 (Original Background Score)
# Ready (Cine Audio)
# National Crush Rashmika Mandanna Hit Songs
# Fresh Face To Tollywood
# Rowdy Boys
# S/o Satyamurthy
# Sakala Devatha Stothrams, Vol. 1
# Uppena
# Manmadan Ambu (Original Motion Picture Soundtrack)
# Rockstar Dsp Birthday Special Hit Songs 2019
# Expression Queen Trisha
# Kotha Kothagaa
# Maharshi
# Rockstar Dsp - Musical Journey
# Dsp Musical Hits
# Golden Star Ganesh Romantic Hits
# Puli (Telugu) [Original Motion Picture Soundtrack]
# Son Of Sathyamoorthi (Original Motion Picture Soundtrack)
# Son Of Satyamurthy
# Devi
# Legend (Telugu)
# Jai Ho
# ...

# %%
results = sp.artist_top_tracks(dsp_uri)
for track in results['tracks'][:10]:
    print('Track:', track['name'])
    print('Audio Preview:', track['preview_url'])
    print('Cover Art:', track['album']['images'][0]['url'])
    print()
# Out:
# Track: Bujji Thalli (From "Thandel")
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b273b21d3fb220ac724c150b9d20
#
# Track: Oo Antava Oo Oo Antava (From "Pushpa - The Rise")(Telugu)
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b2735d10ca5f50f7e9abca322956
#
# Track: Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b273bde2708d57b1fbb64ca2a233
#
# Track: Poyiraa Mama
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b273c5e603c00c6b3527ff6e95b1
#
# Track: Uppenantha
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b2738335d4c9f1240433714f0a33
#
# Track: Daddy Mummy
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b273e1e5abb14d9daf6618d19273
#
# Track: Peelings (From "Pushpa 2 The Rule") [TELUGU]
# Audio Preview: None
# Cover Art: https://i.scdn.co/image/ab67616d0000b2739c3b8606a83a49694b48a126
#
# ...
